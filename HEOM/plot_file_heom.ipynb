# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test1 = np.loadtxt("/u/dem/kebl6911/Part-II/pop_site_tau-50_T-77_init-0_K_0_L_1.dat")
# test2 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_1.dat")
# test3 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_2.dat")
# test4 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_4.dat")
for i in range(1,8):
    plt.plot(test1[:,0],test1[:,i],":")
    #plt.plot(test3[:,0],test3[:,i])
plt.show()
