# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exc_300 L convergence - Run L=4

# %%
test1 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/exc_300/pop_exc_tau-50_T-300_init-0_K_0_L_4.dat")
test2 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/exc_300/pop_exc_tau-50_T-300_init-0_K_0_L_5.dat")
# test4 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_4.dat")
for i in range(1,8):
    plt.plot(test1[:,0],test1[:,i],":")
    plt.plot(test2[:,0],test2[:,i])
plt.show()

# %% [markdown]
# # Site_300 Convergence - L =

# %%
test1 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/site_300/pop_site_tau-50_T-300_init-0_K_0_L_5.dat")
test2 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/site_300/pop_site_tau-50_T-300_init-0_K_0_L_4.dat")
# test4 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_4.dat")
for i in range(1,8):
    plt.plot(test1[:,0],test1[:,i],)
    plt.plot(test2[:,0],test2[:,i])
plt.show()

# %% [markdown]
# # Site_77 Convergence - L=4

# %%
test1 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/site_77/pop_site_tau-50_T-77_init-0_K_0_L_4.dat")
test2 = np.loadtxt("/u/dem/kebl6911/Part-II/HEOM/site_77/pop_site_tau-50_T-77_init-0_K_0_L_5.dat")
# test4 = np.loadtxt("pop_exc_tau-50_T-300_init-0_K_0_L_4.dat")
for i in range(1,8):
    plt.plot(test1[:,0],test1[:,i],)
    plt.plot(test2[:,0],test2[:,i])
plt.show()
