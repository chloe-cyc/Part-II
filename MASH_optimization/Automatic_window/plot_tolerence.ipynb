# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
site_data_path = "/u/dem/kebl6911/Part-II/MASH_optimization/Data/mash_site300K.dat"
plt.rc('axes', labelsize=12) 
plt.rc('legend', fontsize=12)

# %%
site_data = np.loadtxt(site_data_path)

#Error over 1000
site_residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Automatic_window/Percentage_diff.dat")
site_data = site_data[site_data[:,0] <= 1000]

column_names = ["Time"]
plt.plot(site_residual_data[:,0],site_residual_data[:,1], label = "Residual Sum per Number of Data Points in Window of Optimization")
print(site_residual_data[40,1]-site_residual_data[41,1])
# Out:
# 0.008671797121402314

# %%
data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Automatic_window/full_data/208.0241191871772_42.dat")
column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    plt.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    plt.plot(data[:,0],data[:,i], "-",color=c)

plt.show()
