# %%
#IMPORT OF PACKAGES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#No bounds, non-real kappas, +ve eigenvalue = divergence
og_exciton_data = np.loadtxt("../Data/mash_exc300K.dat")
# (no positive values) data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Chloe_Test_File/Plotting_Windows_Chloe/1291.6846470459607_18.dat")
data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Chloe_Test_File/Plotting_Windows_Chloe/2888.148817552204_20.dat")

for i in range(1,8):
    c = "C%i"%i
    plt.plot(og_exciton_data[:, 0], og_exciton_data[:, i], label=f"{i}_og", linestyle="--", color=c)


for i in range(1,8):
    c = "C%i"%i
    plt.plot(data[:, 0], data[:, i], label=f"{i}_ls", linestyle=":",color=c)


plt.xlabel("Time (fs)")
# plt.xlim(0,1000)
# plt.ylim(0,1)
plt.ylabel("Population (1-n)")
# Out:
# Text(0, 0.5, 'Population (1-n)')

# %%
#Bounds, Real kappas = divergence
og_exciton_data = np.loadtxt("../Data/mash_exc300K.dat")
# (no positive values) data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Chloe_Test_File/Plotting_Windows_Chloe/1291.6846470459607_18.dat")
data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Chloe_Test_File/Plotting_Windows_Chloe_Bounded/420.8860085880096_3.dat")

for i in range(1,8):
    c = "C%i"%i
    plt.plot(og_exciton_data[:, 0], og_exciton_data[:, i], label=f"{i}_og", linestyle="--", color=c)


for i in range(1,8):
    c = "C%i"%i
    plt.plot(data[:, 0], data[:, i], label=f"{i}_ls", linestyle=":",color=c)


plt.xlabel("Time (fs)")
# plt.xlim(0,1000)
# plt.ylim(0,1)
plt.ylabel("Population (1-n)")
# Out:
# Text(0, 0.5, 'Population (1-n)')

# %%
file_list = os.listdir("/u/dem/kebl6911/Part-II/MASH_optimization/Chloe_Test_File/Plotting_Windows_Chloe_Bounded")
nrows, ncols = 5, 5
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 10))
axes = axes.flatten()

#MASH Exciton Data
og_exciton_data = np.loadtxt("../Data/mash_exc300K.dat")

#Create column names for df
for index, ax in enumerate(axes):
    file = file_list[index]
    data = np.loadtxt(f"Plotting_Windows_Chloe_Bounded/{file}")

    for i in range(1,8):
        c = "C%i"%i
        ax.plot(og_exciton_data[:, 0], og_exciton_data[:, i], label=f"{i}_og", linestyle="--", color=c)


    for i in range(1,8):
        c = "C%i"%i
        ax.plot(data[:, 0], data[:, i], label=f"{i}_ls", linestyle=":",color=c)

# %%
values = []
for file in file_list:
    file = file.split("_")[0]
    values.append(float(file))

# %%
original_str = "3463.843472977183_18.dat"
parts = original_str.split("_")
result_str = parts[0]
print(result_str)
# Out:
# 3463.843472977183
