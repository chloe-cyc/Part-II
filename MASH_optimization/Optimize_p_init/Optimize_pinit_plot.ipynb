# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
site_data_path = "/u/dem/kebl6911/Part-II/MASH_optimization/Data/mash_site300K.dat"

# %% [markdown]
# # Error over full window of 1000 ps

# %%
site_data = np.loadtxt(site_data_path)

#Error over 1000
site_residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/residualdivided_data_1000.dat")
site_data = site_data[site_data[:,0] <= 1000]

column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
# Create a 2x1 grid of subplots
fig = plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 3])

# Top plot: Square plot
ax0 = plt.subplot(gs[0])
ax0.plot(site_residual_data[:,0],np.log(site_residual_data[:,1]))
# ax0.set_title('Square Plot')
ax0.set_ylabel('ln(Residual Sum per Number of Data Points)')
ax0.set_xlabel('Cut Off Time [fs]')

ax0.plot(site_residual_data[4,0], np.log(site_residual_data[4,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[4,0]+10, np.log(site_residual_data[4,1]), '48.4 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[45,0], np.log(site_residual_data[45,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[45,0]+10, np.log(site_residual_data[45,1]), '445.1 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[97,0], np.log(site_residual_data[97,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[97,0]+10, np.log(site_residual_data[97,1]), '948.2 fs', fontsize=12, ha='left', va='bottom', color='black')

# Bottom row: Three horizontal subplots
gs_sub = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs[1], wspace=0.3)

ax1 = plt.Subplot(fig, gs_sub[0])
ax2 = plt.Subplot(fig, gs_sub[1])
ax3 = plt.Subplot(fig, gs_sub[2])

fig.add_subplot(ax1)
fig.add_subplot(ax2)
fig.add_subplot(ax3)

data_43 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_1000/48.377702136552834_4.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax1.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax1.plot(data_43[:,0],data_43[:,i], ":",color=c)

ax1.set_title('48.4 fs')

data_102 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_1000/445.0748596562861_45.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax2.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax2.plot(data_102[:,0],data_102[:,i], ":",color=c)

# ax2.set_xlabel("Time [fs]")
ax2.set_title('445.1 fs')

data_305 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_1000/948.2029618764356_97.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax3.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax3.plot(data_305[:,0],data_305[:,i], ":",color=c)

ax3.set_title('948.2')
ax3.legend(bbox_to_anchor=(1.2, 1), borderaxespad=0)

# fig.text(0.005, 0.25, r'$P_{\mathrm{1\rightarrow n}}$', va='center', rotation='vertical')
# custom_legend_entry = Line2D([0], [0], linestyle=':', label='Dotted Lines', color='black')

# ax3.set_title('353.2 fs')

# # Define custom legend entries for dotted lines
# dotted_legend_entry = Line2D([0], [0], linestyle=':', label='Optimized Population', color="black")

# # Add the custom legend entries to the legend
# legend_handles, legend_labels = ax3.get_legend_handles_labels()
# legend_handles.append(dotted_legend_entry)
# legend_labels.append('Optimized Population')
# ax3.legend(legend_handles, legend_labels, loc='lower center', bbox_to_anchor=(-0.8, -0.2), borderaxespad=0, ncol=8)  # Adjust the values as needed

# # Adjust spacing between subplots

plt.tight_layout(pad = 0.1)
plt.show()

# %% [markdown]
# # Error over window of optimization

# %%
# Error over only the fitting window:
site_data = np.loadtxt(site_data_path)

#Error over 1000
site_residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/residualdivided_data_window_1.dat")
site_data = site_data[site_data[:,0] <= 1000]

column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
# Create a 2x1 grid of subplots
fig = plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 3])

# Top plot: Square plot
ax0 = plt.subplot(gs[0])
ax0.plot(site_residual_data[:,0],np.log(site_residual_data[:,1]))
# ax0.set_title('Square Plot')
ax0.set_ylabel('ln(Residual Sum per Number of Data Points)')
ax0.set_xlabel('Cut Off Time [fs]')

ax0.plot(site_residual_data[4,0], np.log(site_residual_data[4,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[4,0]+10, np.log(site_residual_data[4,1]), '48.4 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[45,0], np.log(site_residual_data[45,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[45,0]+10, np.log(site_residual_data[45,1]), '445.1 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[97,0], np.log(site_residual_data[97,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[97,0]+10, np.log(site_residual_data[97,1]), '948.2 fs', fontsize=12, ha='left', va='bottom', color='black')

# Bottom row: Three horizontal subplots
gs_sub = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs[1], wspace=0.3)

ax1 = plt.Subplot(fig, gs_sub[0])
ax2 = plt.Subplot(fig, gs_sub[1])
ax3 = plt.Subplot(fig, gs_sub[2])

fig.add_subplot(ax1)
fig.add_subplot(ax2)
fig.add_subplot(ax3)

data_43 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_window_1/48.377702136552834_4.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax1.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax1.plot(data_43[:,0],data_43[:,i], ":",color=c)

ax1.set_title('48.4 fs')

data_102 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_window_1/445.0748596562861_45.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax2.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax2.plot(data_102[:,0],data_102[:,i], ":",color=c)

# ax2.set_xlabel("Time [fs]")
ax2.set_title('445.1 fs')

data_305 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Error_over_window_1/948.2029618764356_97.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax3.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax3.plot(data_305[:,0],data_305[:,i], ":",color=c)

ax3.set_title('948.2')
ax3.legend(bbox_to_anchor=(1.2, 1), borderaxespad=0)

# fig.text(0.005, 0.25, r'$P_{\mathrm{1\rightarrow n}}$', va='center', rotation='vertical')
# custom_legend_entry = Line2D([0], [0], linestyle=':', label='Dotted Lines', color='black')

# ax3.set_title('353.2 fs')

# # Define custom legend entries for dotted lines
# dotted_legend_entry = Line2D([0], [0], linestyle=':', label='Optimized Population', color="black")

# # Add the custom legend entries to the legend
# legend_handles, legend_labels = ax3.get_legend_handles_labels()
# legend_handles.append(dotted_legend_entry)
# legend_labels.append('Optimized Population')
# ax3.legend(legend_handles, legend_labels, loc='lower center', bbox_to_anchor=(-0.8, -0.2), borderaxespad=0, ncol=8)  # Adjust the values as needed

# # Adjust spacing between subplots

plt.tight_layout(pad = 0.1)
plt.show()

# %% [markdown]
# # Starting optimization from time, t. Residual divided by optimization window

# %%
# Error over only the fitting window:
site_data = np.loadtxt(site_data_path)

#Error over 1000
site_residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/residual_start_window_divided.dat")
site_data = site_data[site_data[:,0] <= 1000]

column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
# Create a 2x1 grid of subplots
fig = plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 3])

# Top plot: Square plot
ax0 = plt.subplot(gs[0])
ax0.plot(site_residual_data[:,0],np.log(site_residual_data[:,1]))
# ax0.set_title('Square Plot')
ax0.set_ylabel('ln(Residual Sum per Number of Data Points used in Optimization)')
ax0.set_xlabel('Cut Off Time [fs]')

ax0.plot(site_residual_data[6,0], np.log(site_residual_data[6,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[6,0]+10, np.log(site_residual_data[6,1]), '48.4 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[33,0], np.log(site_residual_data[33,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[33,0]+10, np.log(site_residual_data[33,1]), '309.6 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[69,0], np.log(site_residual_data[69,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[69,0]+10, np.log(site_residual_data[69,1]), '657.9 fs', fontsize=12, ha='left', va='bottom', color='black')

# Bottom row: Three horizontal subplots
gs_sub = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs[1], wspace=0.3)

ax1 = plt.Subplot(fig, gs_sub[0])
ax2 = plt.Subplot(fig, gs_sub[1])
ax3 = plt.Subplot(fig, gs_sub[2])

fig.add_subplot(ax1)
fig.add_subplot(ax2)
fig.add_subplot(ax3)

data_43 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/start_window/48.377702136552834_6.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax1.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax1.plot(data_43[:,0],data_43[:,i], ":",color=c)

ax1.set_title('48.4 fs')

data_102 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/start_window/309.6172936739381_33.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax2.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax2.plot(data_102[:,0],data_102[:,i], ":",color=c)

# ax2.set_xlabel("Time [fs]")
ax2.set_title('309.6 fs')

data_305 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/start_window/657.9367490571185_69.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax3.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax3.plot(data_305[:,0],data_305[:,i], ":",color=c)

ax3.set_title('657.9')
ax3.legend(bbox_to_anchor=(1.2, 1), borderaxespad=0)

fig.text(0.005, 0.25, r'$P_{\mathrm{1\rightarrow n}}$', va='center', rotation='vertical')
custom_legend_entry = Line2D([0], [0], linestyle=':', label='Dotted Lines', color='black')


# Define custom legend entries for dotted lines
dotted_legend_entry = Line2D([0], [0], linestyle=':', label='Optimized Population', color="black")

# Add the custom legend entries to the legend
legend_handles, legend_labels = ax3.get_legend_handles_labels()
legend_handles.append(dotted_legend_entry)
legend_labels.append('Optimized Population')
ax3.legend(legend_handles, legend_labels, loc='lower center', bbox_to_anchor=(-0.8, -0.2), borderaxespad=0, ncol=8)  # Adjust the values as needed

# Adjust spacing between subplots

plt.tight_layout(pad = 0.1)
plt.show()

# %%
# Error over only the fitting window:
site_data = np.loadtxt(site_data_path)

#Error over 1000
site_residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Residual_nonegpop.dat")
site_data = site_data[site_data[:,0] <= 1000]

column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
# Create a 2x1 grid of subplots
fig = plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 3])

# Top plot: Square plot
ax0 = plt.subplot(gs[0])
ax0.plot(site_residual_data[:,0],np.log(site_residual_data[:,1]))
# ax0.set_title('Square Plot')
ax0.set_ylabel('ln(Residual Sum per Number of Data Points used in Optimization)')
ax0.set_xlabel('Cut Off Time [fs]')
# Python arrays start at zero you ideoit
ax0.plot(site_residual_data[26,0], np.log(site_residual_data[26,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[26,0]+10, np.log(site_residual_data[26,1]), '251.6', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[34,0], np.log(site_residual_data[34,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[34,0]+10, np.log(site_residual_data[34,1]), '329.0 fs', fontsize=12, ha='left', va='bottom', color='black')

ax0.plot(site_residual_data[25,0], np.log(site_residual_data[25,1]), 'x', markersize=8, color = 'black')
ax0.text(site_residual_data[25,0]+10, np.log(site_residual_data[25,1]), '241.9 fs', fontsize=12, ha='left', va='bottom', color='black')

# Bottom row: Three horizontal subplots
gs_sub = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs[1], wspace=0.3)

ax1 = plt.Subplot(fig, gs_sub[0])
ax2 = plt.Subplot(fig, gs_sub[1])
ax3 = plt.Subplot(fig, gs_sub[2])

fig.add_subplot(ax1)
fig.add_subplot(ax2)
fig.add_subplot(ax3)

data_43 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Start_window_no_negatives/251.56405111007473_27.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax1.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax1.plot(data_43[:,0],data_43[:,i], "-",color=c)

ax1.set_title('251.6 fs')

data_102 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Start_window_no_negatives/328.96837452855925_35.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax2.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax2.plot(data_102[:,0],data_102[:,i], "-",color=c)

# ax2.set_xlabel("Time [fs]")
ax2.set_title('329.0 fs')

#ax2.set_xlim(300,400)
data_305 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Start_window_no_negatives/241.88851068276415_26.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    ax3.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    ax3.plot(data_305[:,0],data_305[:,i], ":",color=c)

ax3.set_title('241.9')
ax3.legend(bbox_to_anchor=(1.2, 1), borderaxespad=0)

fig.text(0.005, 0.25, r'$P_{\mathrm{1\rightarrow n}}$', va='center', rotation='vertical')
custom_legend_entry = Line2D([0], [0], linestyle=':', label='Dotted Lines', color='black')


# Define custom legend entries for dotted lines
dotted_legend_entry = Line2D([0], [0], linestyle=':', label='Optimized Population', color="black")

# Add the custom legend entries to the legend
legend_handles, legend_labels = ax3.get_legend_handles_labels()
legend_handles.append(dotted_legend_entry)
legend_labels.append('Optimized Population')
ax3.legend(legend_handles, legend_labels, loc='lower center', bbox_to_anchor=(-0.8, -0.2), borderaxespad=0, ncol=8)  # Adjust the values as needed

# Adjust spacing between subplots

plt.tight_layout(pad = 0.1)
plt.show()

# %%
data_102 = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Optimize_p_init/Start_window_no_negatives/309.6172936739381_33.dat")
for i, column_name in enumerate(column_names[1:], start=1):
    c = "C%i"%i
    plt.plot(site_data[:,0], site_data[:,i],"--", label=column_name, color=c)
    plt.plot(data_102[:,0],data_102[:,i], ":",color=c)

# ax2.set_xlabel("Time [fs]")
plt.title('319.3 fs')
#plt.xlim(200,600)
# Out:
# Text(0.5, 1.0, '319.3 fs')
