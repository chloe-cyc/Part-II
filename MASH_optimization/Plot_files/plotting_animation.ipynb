# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.widgets import Slider

# %%
file_names = os.listdir("Window_data")
print(len(file_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bceres.chem.ox.ac.uk/u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> file_names = os.listdir("Window_data")
#       <a href='vscode-notebook-cell://ssh-remote%2Bceres.chem.ox.ac.uk/u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(len(file_names))
#
# NameError: name 'os' is not defined

# %%
og_exciton_data = np.loadtxt("Data/mash_exc300K.dat")
fig, ax = plt.subplots(figsize=(8, 6))

def plot_file(file_index):
    file = file_names[file_index]
    data = np.loadtxt(f"Window_data/{file}")

    ax.clear()

    for i in range(1,8):
        c = "C%i" % i
        ax.plot(og_exciton_data[:, 0], og_exciton_data[:, i], label=f"{i}_og", linestyle="--", color=c)


    for i in range(1,8):
        c = "C%i" % i
        ax.plot(data[:, 0], data[:, i], label=f"{i}_ls", color=c)


    ax.set_xlabel("Time")
    ax.set_ylabel("Population(1-n)")
    ax.legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)
    
slider = widgets.IntSlider(
    value=1, min=1, max=len(file_names), step=1
)

plot_file(slider.value)
#Function updates plot when slider changes
def slider_change(change):
    plot_file(change.new)

# Connect the slider to the function using observe
slider.observe(slider_change, names="value")

# Use interact to display the slider and update the plot
widgets.interact(plot_file, file_index=slider)

# Display the initial plot
plot_file(0)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bceres.chem.ox.ac.uk/u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> og_exciton_data = np.loadtxt("Data/mash_exc300K.dat")
#       <a href='vscode-notebook-cell://ssh-remote%2Bceres.chem.ox.ac.uk/u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> fig, ax = plt.subplots(figsize=(8, 6))
#       <a href='vscode-notebook-cell://ssh-remote%2Bceres.chem.ox.ac.uk/u/dem/kebl6911/Part-II/MASH_optimization/plotting_animation.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> def plot_file(file_index):
#
# NameError: name 'np' is not defined

# %%
og_exciton_data = np.loadtxt("Data/mash_exc300K.dat")
fig, ax = plt.subplots(figsize=(8, 6))

ax_slider = plt.axes([0.25, 0.02, 0.65, 0.03], facecolor='lightgoldenrodyellow')
slider = Slider(ax_slider, 'Select File', 0, len(file_names) - 1, valinit=0, valstep=1)

def update(val):
    file_index = int(slider.val)
    file = file_names[file_index]
    data = np.loadtxt(f"Window_data/{file}")

    ax.clear()

    # Plot the 'og_exciton_data' in the background
    for i in range(8):
        c = "C%i" % i
        ax.plot(og_exciton_data[:, 0], og_exciton_data[:, i], label=f"{i}_og", linestyle="--", color=c)

    # Plot the data from the selected file on top
    for i in range(8):
        c = "C%i" % i
        ax.plot(data[:, 0], data[:, i], label=f"{i}_ls", color=c)

    ax.set_xlabel("Time")
    ax.set_ylabel("Population(1-n)")
    ax.legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)
    plt.draw()

# Connect the slider to the update function
slider.on_changed(update)

# Display the initial plot
update(0)

# %%
og_exciton_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Window_data/2883.3110473385486_15.dat")
for i in range(1,8):
    c = "C%i"%i
    plt.plot(og_exciton_data[:,0], og_exciton_data[:,i], label = f"{i}", color = c)

plt.show()
