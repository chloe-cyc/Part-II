# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
site_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Data/mash_site300K.dat")

# %%
site_data_path = "/u/dem/kebl6911/Part-II/MASH_optimization/Data/mash_site300K.dat"
column_names = ["Time"]
for i in range(1,8):
    column_names.append(str(i))
site_df = pd.read_csv(site_data_path, delimiter=" ", names=column_names)
site_df = site_df[(site_df.index % 30 == 0) | (site_df.index == len(site_df.index) - 1)]
start_time_values = np.array(site_df['Time'].iloc[4::5])
start_time_values=start_time_values[:-2]

row_counts = []
for start_time in start_time_values:
    count = len(site_df[site_df['Time'] >= start_time])
    row_counts.append(count)

row_counts = np.array(row_counts)

# %%
residual_data = np.loadtxt("/u/dem/kebl6911/Part-II/MASH_optimization/Site_data_cut/residual_data.dat")

plt.plot(residual_data[:,0],residual_data[:,1])
plt.xlabel("Time")
plt.ylabel("Residual Sum over Count")
# Out:
# Text(0, 0.5, 'Residual Sum over Count')

# %%
ls_data = np.readtxt("")
